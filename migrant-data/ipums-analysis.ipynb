# %%
import pandas as pd

# %%
# load my IPUMS chicago query
df = pd.read_csv('chi_ipums_10.11.23.csv')

# %%
df.head(2)
# Out:
#    YEAR  SAMPLE  SERIAL  CBSERIAL   HHWT        CLUSTER  STATEFIP  COUNTYFIP  \
# 0  1850  185001  330301       NaN  98.34  1850003303011        17        NaN
# 1  1850  185001  330301       NaN  98.34  1850003303011        17        NaN
#
#    CITY       STRATA  ...  LIT  EMPSTAT  EMPSTATD  OCC1990  WORKEDYR  POVERTY  \
# 0  1190  10211703100  ...  1.0      NaN       NaN      NaN       NaN      NaN
# 1  1190  10211703100  ...  4.0      NaN       NaN      NaN       NaN      NaN
#
#    MIGRATE1  MIGRATE1D  MIGPLAC1  MIGCITY1
# 0       NaN        NaN       NaN       NaN
# 1       NaN        NaN       NaN       NaN
#
# [2 rows x 35 columns]

# %%
# what years did I pull?
df.groupby('YEAR').size().reset_index()
# Out:
#     YEAR      0
# 0   1850    312
# 1   1860   1109
# 2   1870   2846
# 3   1880   4918
# 4   1900  16701
# 5   1910  20839
# 6   1920  27073
# 7   1930  33703
# 8   1940  34447
# 9   1950  42532
# 10  1980  30063
# 11  1990  21467
# 12  2000  22229
# 13  2005  19624
# 14  2006  20714
# 15  2007  20546
# 16  2008  20616
# 17  2009  20789
# 18  2010  21120
# 19  2011  22842
# 20  2012  22536
# 21  2013  22611
# 22  2014  22632
# 23  2015  22107
# 24  2016  21838
# 25  2017  21618
# 26  2018  20605
# 27  2019  20298
# 28  2020  19216
# 29  2021  19764

# %%
# add in birthplace codes
bpl = pd.read_csv('IPUMS codes - BPL.csv')

# %%
df = pd.merge(df, bpl, left_on='BPL', right_on='bpl')

# %%
# create a dict of census years and corresponding immigration years
year_dict = {1900:1899,
            1910:1909,
            1920:1919,
            1930:1929,
            1980:1975,
            1990:1987,
            2000:1999,
            2005:2004,
            2006:2005,
            2007:2006,
            2008:2007,
            2009:2008,
            2010:2009,
            2011:2010,
            2012:2011,
            2013:2012,
            2014:2013,
            2015:2014,
            2016:2015,
            2017:2016,
            2018:2017,
            2019:2018,
            2020:2019,
            2021:2020}

# %%
# inspect 1980 to see what YRIMMIG are avail - 1975
df[df['YEAR'] == 1980].groupby('YRIMMIG').size().reset_index()
# Out:
#    YRIMMIG      0
# 0      0.0  25556
# 1   1949.0    847
# 2   1950.0    681
# 3   1960.0    266
# 4   1965.0    580
# 5   1970.0    891
# 6   1975.0   1242

# %%
# inspect 1990 to see what YRIMMIG are avail - 1987
df[df['YEAR'] == 1990].groupby('YRIMMIG').size().reset_index()
# Out:
#     YRIMMIG      0
# 0       0.0  17189
# 1    1949.0    303
# 2    1950.0    404
# 3    1960.0    235
# 4    1965.0    370
# 5    1970.0    494
# 6    1975.0    630
# 7    1980.0    396
# 8    1982.0    369
# 9    1985.0    420
# 10   1987.0    657

# %%
# inspect 2000 to see what YRIMMIG are avail - 1987
df[df['YEAR'] == 2000].groupby('YRIMMIG').size().reset_index()
# Out:
#     YRIMMIG      0
# 0       0.0  16868
# 1    1910.0      1
# 2    1914.0      2
# 3    1919.0      2
# 4    1920.0      2
# ..      ...    ...
# 73   1996.0    204
# 74   1997.0    198
# 75   1998.0    282
# 76   1999.0    322
# 77   2000.0    106
#
# [78 rows x 2 columns]

# %%
# loop through all years

temp_list = [] # create a list of pivot table dataframes

for key,value in year_dict.items():
    
    # create the temp pivot table
    temp = pd.pivot_table(df[(df['YEAR'] == key) & (df['YRIMMIG'] == value)],
              values='PERWT',
              index='bpl_desc',
              columns='YRIMMIG',
              aggfunc='sum').reset_index()
    
    # rename pivot table cols
    temp.columns = ['birthplace', key]
    
    # add each df to the list
    temp_list.append(temp)

# %%
# merge all the lists together
merged = pd.merge(temp_list[0],temp_list[1], on='birthplace', how='outer')

for i in range(2,24,1): # loop through list index 2 inclusive thru 27 inclusive
    # merge each successive year 
    merged = pd.merge(merged,temp_list[i], on='birthplace', how='outer')

# %%
merged
# Out:
#         birthplace    1900    1910    1920    1930    1980    1990    2000  \
# 0          Austria   600.0  8630.0     NaN     NaN   200.0     NaN     NaN
# 1           Canada  1002.0  2006.0  901.62  403.80   300.0   465.0   312.0
# 2            China   100.0     NaN     NaN     NaN  2700.0  4620.0  1201.0
# 3   Czechoslovakia   502.0     NaN  200.36  504.75     NaN   120.0   416.0
# 4          Denmark   100.0   200.0  200.36     NaN   100.0     NaN     NaN
# ..             ...     ...     ...     ...     ...     ...     ...     ...
# 64    Saudi Arabia     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 65          Kuwait     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 66     Afghanistan     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 67          Cyprus     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 68    Other n.e.c.     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#      2005    2006  ...    2012    2013    2014    2015    2016    2017  \
# 0     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN    84.0
# 1     NaN   355.0  ...  1082.0   189.0     NaN   501.0   541.0  1521.0
# 2   870.0  1260.0  ...  3248.0  3014.0  3378.0  4493.0  2847.0  2451.0
# 3     NaN     NaN  ...     NaN     NaN   563.0     NaN     NaN   223.0
# 4     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# ..    ...     ...  ...     ...     ...     ...     ...     ...     ...
# 64    NaN     NaN  ...   329.0    44.0   943.0   163.0   513.0   761.0
# 65    NaN     NaN  ...     NaN   113.0     NaN     NaN     NaN     NaN
# 66    NaN     NaN  ...     NaN     NaN     NaN   799.0     NaN     NaN
# 67    NaN     NaN  ...     NaN     NaN     NaN   129.0     NaN     NaN
# 68    NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN    66.0
#
#       2018    2019    2020   2021
# 0      NaN     NaN     NaN    NaN
# 1    389.0    57.0    70.0  113.0
# 2   3092.0  1105.0  3700.0  737.0
# 3      NaN     NaN     NaN    NaN
# 4      NaN     NaN     NaN    NaN
# ..     ...     ...     ...    ...
# 64     NaN     NaN     NaN    NaN
# 65     NaN     NaN     NaN    NaN
# 66     NaN     NaN     NaN    NaN
# 67     NaN     NaN     NaN    NaN
# 68     NaN     NaN     NaN    NaN
#
# [69 rows x 25 columns]

# %%
# export merged
merged.to_csv('processed/migrants_bpl_1900_2021.csv')
